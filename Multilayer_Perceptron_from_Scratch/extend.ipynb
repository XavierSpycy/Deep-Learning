# %%
import matplotlib.pyplot as plt
from MLPClassifier import Dataset, HiddenLayer, MLP

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = Dataset(random_state=0).load(normalize=True)

# %% [markdown]
# #### Structure 1

# %%
layer1 = HiddenLayer(128, 16, activation='softplus')
layer2 = HiddenLayer(16, 16, batch_norm=True)
layer3 = HiddenLayer(16, 10, activation='softmax') 
layers = [layer1, layer2, layer3]
nn = MLP(layers, optimizer='adagrad', hyperparams={'learning_rate': 0.001})
loss = nn.fit(X_train, y_train, epochs=500, batch_size=32)

# %%
print("Accuracy on training set: {:.2f}%".format(nn.accuracy_score(X_train, y_train)*100))
print("Accuracy on validation set: {:.2f}%".format(nn.accuracy_score(X_valid, y_valid)*100))
print("Training time: {:.0f} sec".format(nn.train_time))
print("Loss: {:.4f}".format(loss[-1]))
# Out:
# Accuracy on training set: 38.89%
# Accuracy on validation set: 37.82%
# Training time: 168 sec
# Loss: 1.7639

# %%
plt.plot(loss)

# %% [markdown]
# #### Structure 2

# %%
layer1 = HiddenLayer(128, 48, activation='softplus')
layer2 = HiddenLayer(48, 48, batch_norm=True)
layer3 = HiddenLayer(48, 24, activation='softplus')
layer4 = HiddenLayer(24, 24, batch_norm=True)
layer5 = HiddenLayer(24, 10, activation='softmax')
layers = [layer1, layer2, layer3, layer4, layer5]
nn = MLP(layers, optimizer='adagrad', hyperparams={'learning_rate': 0.001})
loss = nn.fit(X_train, y_train, epochs=500, batch_size=32)

# %%
print("Accuracy on training set: {:.2f}%".format(nn.accuracy_score(X_train, y_train)*100))
print("Accuracy on validation set: {:.2f}%".format(nn.accuracy_score(X_valid, y_valid)*100))
print("Training time: {:.0f} sec".format(nn.train_time))
print("Loss: {:.4f}".format(loss[-1]))
# Out:
# Accuracy on training set: 40.73%
# Accuracy on validation set: 39.36%
# Training time: 335 sec
# Loss: 1.7300

# %%
plt.plot(loss)

# %% [markdown]
# #### Structure 3

# %%
layer1 = HiddenLayer(128, 64, activation='softplus')
layer2 = HiddenLayer(64, 64, batch_norm=True)
layer3 = HiddenLayer(64, 32, activation='softplus')
layer4 = HiddenLayer(32, 32, batch_norm=True)
layer5 = HiddenLayer(32, 16, activation='softplus')
layer6 = HiddenLayer(16, 16, batch_norm=True)
layer7 = HiddenLayer(16, 10, activation='softmax')
layers = [layer1, layer2, layer3, layer4, layer5, layer6, layer7]
nn = MLP(layers, optimizer='adagrad', hyperparams={'learning_rate': 0.001})
loss = nn.fit(X_train, y_train, epochs=500, batch_size=32)

# %%
print("Accuracy on training set: {:.2f}%".format(nn.accuracy_score(X_train, y_train)*100))
print("Accuracy on validation set: {:.2f}%".format(nn.accuracy_score(X_valid, y_valid)*100))
print("Training time: {:.0f} sec".format(nn.train_time))
print("Loss: {:.4f}".format(loss[-1]))
# Out:
# Accuracy on training set: 40.54%
# Accuracy on validation set: 39.44%
# Training time: 475 sec
# Loss: 1.7233

# %%
plt.plot(loss)

# %% [markdown]
# #### Learning rate = 0.1

# %%
layer1 = HiddenLayer(128, 48, activation='softplus')
layer2 = HiddenLayer(48, 48, batch_norm=True)
layer3 = HiddenLayer(48, 24, activation='softplus')
layer4 = HiddenLayer(24, 24, batch_norm=True)
layer5 = HiddenLayer(24, 10, activation='softmax')
layers = [layer1, layer2, layer3, layer4, layer5]
nn = MLP(layers, optimizer='adagrad', hyperparams={'learning_rate': 0.1})
loss = nn.fit(X_train, y_train, epochs=500, batch_size=32)

# %%
print("Accuracy on training set: {:.2f}%".format(nn.accuracy_score(X_train, y_train)*100))
print("Accuracy on validation set: {:.2f}%".format(nn.accuracy_score(X_valid, y_valid)*100))
print("Training time: {:.0f} sec".format(nn.train_time))
print("Loss: {:.4f}".format(loss[-1]))
# Out:
# Accuracy on training set: 50.08%
# Accuracy on validation set: 44.84%
# Training time: 331 sec
# Loss: 1.4910

# %%
plt.plot(loss)

# %% [markdown]
# #### Learning rate = 0.01

# %%
layer1 = HiddenLayer(128, 48, activation='softplus')
layer2 = HiddenLayer(48, 48, batch_norm=True)
layer3 = HiddenLayer(48, 24, activation='softplus')
layer4 = HiddenLayer(24, 24, batch_norm=True)
layer5 = HiddenLayer(24, 10, activation='softmax')
layers = [layer1, layer2, layer3, layer4, layer5]
nn = MLP(layers, optimizer='adagrad', hyperparams={'learning_rate': 0.01})
loss = nn.fit(X_train, y_train, epochs=500, batch_size=32)

# %%
print("Accuracy on training set: {:.2f}%".format(nn.accuracy_score(X_train, y_train)*100))
print("Accuracy on validation set: {:.2f}%".format(nn.accuracy_score(X_valid, y_valid)*100))
print("Training time: {:.0f} sec".format(nn.train_time))
print("Loss: {:.4f}".format(loss[-1]))
# Out:
# Accuracy on training set: 52.44%
# Accuracy on validation set: 46.96%
# Training time: 330 sec
# Loss: 1.4227

# %%
plt.plot(loss)

# %% [markdown]
# #### Learning rate = 0.001

# %%
layer1 = HiddenLayer(128, 48, activation='softplus')
layer2 = HiddenLayer(48, 48, batch_norm=True)
layer3 = HiddenLayer(48, 24, activation='softplus')
layer4 = HiddenLayer(24, 24, batch_norm=True)
layer5 = HiddenLayer(24, 10, activation='softmax')
layers = [layer1, layer2, layer3, layer4, layer5]
nn = MLP(layers, optimizer='adagrad', hyperparams={'learning_rate': 0.001})
loss = nn.fit(X_train, y_train, epochs=500, batch_size=32)

# %%
print("Accuracy on training set: {:.2f}%".format(nn.accuracy_score(X_train, y_train)*100))
print("Accuracy on validation set: {:.2f}%".format(nn.accuracy_score(X_valid, y_valid)*100))
print("Training time: {:.0f} sec".format(nn.train_time))
print("Loss: {:.4f}".format(loss[-1]))
# Out:
# Accuracy on training set: 41.00%
# Accuracy on validation set: 39.54%
# Training time: 331 sec
# Loss: 1.7173

# %%
plt.plot(loss)

# %% [markdown]
# #### Batch size = 16

# %%
layer1 = HiddenLayer(128, 48, activation='softplus')
layer2 = HiddenLayer(48, 48, batch_norm=True)
layer3 = HiddenLayer(48, 24, activation='softplus')
layer4 = HiddenLayer(24, 24, batch_norm=True)
layer5 = HiddenLayer(24, 10, activation='softmax')
layers = [layer1, layer2, layer3, layer4, layer5]
nn = MLP(layers, optimizer='adagrad', hyperparams={'learning_rate': 0.01})
loss = nn.fit(X_train, y_train, epochs=500, batch_size=16)

# %%
print("Accuracy on training set: {:.2f}%".format(nn.accuracy_score(X_train, y_train)*100))
print("Accuracy on validation set: {:.2f}%".format(nn.accuracy_score(X_valid, y_valid)*100))
print("Training time: {:.0f} sec".format(nn.train_time))
print("Loss: {:.4f}".format(loss[-1]))
# Out:
# Accuracy on training set: 49.65%
# Accuracy on validation set: 45.52%
# Training time: 557 sec
# Loss: 1.5346

# %%
plt.plot(loss)

# %% [markdown]
# #### Batch size = 32

# %%
layer1 = HiddenLayer(128, 48, activation='softplus')
layer2 = HiddenLayer(48, 48, batch_norm=True)
layer3 = HiddenLayer(48, 24, activation='softplus')
layer4 = HiddenLayer(24, 24, batch_norm=True)
layer5 = HiddenLayer(24, 10, activation='softmax')
layers = [layer1, layer2, layer3, layer4, layer5]
nn = MLP(layers, optimizer='adagrad', hyperparams={'learning_rate': 0.01})
loss = nn.fit(X_train, y_train, epochs=500, batch_size=32)

# %%
print("Accuracy on training set: {:.2f}%".format(nn.accuracy_score(X_train, y_train)*100))
print("Accuracy on validation set: {:.2f}%".format(nn.accuracy_score(X_valid, y_valid)*100))
print("Training time: {:.0f} sec".format(nn.train_time))
print("Loss: {:.4f}".format(loss[-1]))
# Out:
# Accuracy on training set: 49.01%
# Accuracy on validation set: 44.50%
# Training time: 339 sec
# Loss: 1.4924

# %%
plt.plot(loss)

# %% [markdown]
# #### Batch size = 64

# %%
layer1 = HiddenLayer(128, 48, activation='softplus')
layer2 = HiddenLayer(48, 48, batch_norm=True)
layer3 = HiddenLayer(48, 24, activation='softplus')
layer4 = HiddenLayer(24, 24, batch_norm=True)
layer5 = HiddenLayer(24, 10, activation='softmax')
layers = [layer1, layer2, layer3, layer4, layer5]
nn = MLP(layers, optimizer='adagrad', hyperparams={'learning_rate': 0.01})
loss = nn.fit(X_train, y_train, epochs=500, batch_size=64)

# %%
print("Accuracy on training set: {:.2f}%".format(nn.accuracy_score(X_train, y_train)*100))
print("Accuracy on validation set: {:.2f}%".format(nn.accuracy_score(X_valid, y_valid)*100))
print("Training time: {:.0f} sec".format(nn.train_time))
print("Loss: {:.4f}".format(loss[-1]))
# Out:
# Accuracy on training set: 52.04%
# Accuracy on validation set: 46.54%
# Training time: 288 sec
# Loss: 1.3930

# %%
plt.plot(loss)

# %% [markdown]
# #### Optimizer: Adadelta

# %%
layer1 = HiddenLayer(128, 48, activation='softplus')
layer2 = HiddenLayer(48, 48, batch_norm=True)
layer3 = HiddenLayer(48, 24, activation='softplus')
layer4 = HiddenLayer(24, 24, batch_norm=True)
layer5 = HiddenLayer(24, 10, activation='softmax')
layers = [layer1, layer2, layer3, layer4, layer5]
nn = MLP(layers, optimizer='adadelta', hyperparams={'learning_rate': 0.01})
loss = nn.fit(X_train, y_train, epochs=500, batch_size=32)

# %%
print("Accuracy on training set: {:.2f}%".format(nn.accuracy_score(X_train, y_train)*100))
print("Accuracy on validation set: {:.2f}%".format(nn.accuracy_score(X_valid, y_valid)*100))
print("Training time: {:.0f} sec".format(nn.train_time))
print("Loss: {:.4f}".format(loss[-1]))
# Out:
# Accuracy on training set: 49.90%
# Accuracy on validation set: 45.72%
# Training time: 414 sec
# Loss: 1.4974

# %%
plt.plot(loss)

# %% [markdown]
# #### Optimizer: Adagrad

# %%
layer1 = HiddenLayer(128, 48, activation='softplus')
layer2 = HiddenLayer(48, 48, batch_norm=True)
layer3 = HiddenLayer(48, 24, activation='softplus')
layer4 = HiddenLayer(24, 24, batch_norm=True)
layer5 = HiddenLayer(24, 10, activation='softmax')
layers = [layer1, layer2, layer3, layer4, layer5]
nn = MLP(layers, optimizer='adagrad', hyperparams={'learning_rate': 0.01})
loss = nn.fit(X_train, y_train, epochs=500, batch_size=32)

# %%
print("Accuracy on training set: {:.2f}%".format(nn.accuracy_score(X_train, y_train)*100))
print("Accuracy on validation set: {:.2f}%".format(nn.accuracy_score(X_valid, y_valid)*100))
print("Training time: {:.0f} sec".format(nn.train_time))
print("Loss: {:.4f}".format(loss[-1]))
# Out:
# Accuracy on training set: 49.86%
# Accuracy on validation set: 45.14%
# Training time: 341 sec
# Loss: 1.4720

# %%
plt.plot(loss)
